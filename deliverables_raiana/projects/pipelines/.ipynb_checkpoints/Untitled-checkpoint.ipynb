# %%
import pandas as pd

# %%
suicide = pd.read_csv("suicide-rates-overview-1985-to-2016.zip")

# %%
suicide.head(10)
country = suicide.groupby("country")

# %%
#what do i wanna know? brazil general tendency, gender diff, age diff compare with global

# %%
brsui = country.get_group("Brazil")
brsui.head(10)
# Out:
#      country  year     sex          age  suicides_no  population  \
# 4172  Brazil  1985    male    75+ years          129      840300
# 4173  Brazil  1985    male  55-74 years          535     5364900
# 4174  Brazil  1985    male  35-54 years         1011    11986300
# 4175  Brazil  1985    male  25-34 years          791    10762900
# 4176  Brazil  1985    male  15-24 years          661    13834000
# 4177  Brazil  1985  female    75+ years           32      988100
# 4178  Brazil  1985  female  55-74 years          148     5650100
# 4179  Brazil  1985  female  25-34 years          269    10798700
# 4180  Brazil  1985  female  35-54 years          296    12185200
# 4181  Brazil  1985  female  15-24 years          280    13751800
#
#       suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 4172              15.35   Brazil1985         0.576    222,942,790,435
# 4173               9.97   Brazil1985         0.576    222,942,790,435
# 4174               8.43   Brazil1985         0.576    222,942,790,435
# 4175               7.35   Brazil1985         0.576    222,942,790,435
# 4176               4.78   Brazil1985         0.576    222,942,790,435
# 4177               3.24   Brazil1985         0.576    222,942,790,435
# 4178               2.62   Brazil1985         0.576    222,942,790,435
# 4179               2.49   Brazil1985         0.576    222,942,790,435
# 4180               2.43   Brazil1985         0.576    222,942,790,435
# 4181               2.04   Brazil1985         0.576    222,942,790,435
#
#       gdp_per_capita ($)       generation
# 4172                1898  G.I. Generation
# 4173                1898  G.I. Generation
# 4174                1898           Silent
# 4175                1898          Boomers
# 4176                1898     Generation X
# 4177                1898  G.I. Generation
# 4178                1898  G.I. Generation
# 4179                1898          Boomers
# 4180                1898           Silent
# 4181                1898     Generation X

# %%
year = brsui.groupby("year")
years = year.sum()
# Out:
#       suicides_no  population  suicides/100k pop  HDI for year  \
# year
# 1985         4228   117478900              59.18         6.912
# 1986         4271   118776400              57.16         0.000
# 1987         4672   122822467              70.12         0.000
# 1988         4466   125701294              65.36         0.000
# 1989         4463   128570308              64.02         0.000
# 1990         4803   131387553              67.06         7.296
# 1991         5156   134281850              68.34         0.000
# 1992         5207   137007021              64.92         0.000
# 1993         5508   139615477              67.86         0.000
# 1994         5896   142188450              71.51         0.000
# 1995         6536   144783591              75.24         7.776
# 1996         6698   147353130              73.33         0.000
# 1997         6891   149932627              76.80         0.000
# 1998         6922   152524311              75.05         0.000
# 1999         6507   155122073              67.65         0.000
# 2000         6763   157715991              68.23         8.196
# 2001         7710   160178796              73.49         0.000
# 2002         7697   162761414              69.77         0.000
# 2003         7839   165396911              68.07         0.000
# 2004         7995   167993068              70.22         0.000
# 2005         8529   170483960              73.60         8.424
# 2006         8618   172974722              69.90         0.000
# 2007         8855   175293192              71.68         0.000
# 2008         9184   177471632              72.21         0.000
# 2009         9346   179569551              70.37         0.000
# 2010         9429   181629712              72.73         8.844
# 2011         9822   183656441              72.41         8.904
# 2012        10295   185591215              74.45         8.952
# 2013        10513   187458852              73.41         9.024
# 2014        10631   189285554              73.13         9.060
# 2015        11163   191087085              77.45         0.000
#
#       gdp_per_capita ($)
# year
# 1985               22776
# 1986               27084
# 1987               28728
# 1988               31536
# 1989               39720
# 1990               42192
# 1991               53880
# 1992               35088
# 1993               37632
# 1994               47100
# 1995               63756
# 1996               69252
# 1997               70692
# 1998               67956
# 1999               46368
# 2000               49872
# 2001               41904
# 2002               37452
# 2003               40512
# 2004               47808
# 2005               62760
# 2006               76836
# 2007               95640
# 2008              114660
# 2009              111396
# 2010              145932
# 2011              170940
# 2012              159396
# 2013              158292
# 2014              155700
# 2015              113172

# %% [raw]
# years.head()

# %%
(year.sum()).hist(index,"suicides/100k pop")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-8cdfb552556f> in <module>()
# ----> 1 (year.sum()).hist(index,"suicides/100k pop")
#
# NameError: name 'index' is not defined

# %%
age = brsui.groupby("age")

# %%
 age.get_group("75+ years").hist("suicides_no")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000018B18087BE0>]],
#       dtype=object)
