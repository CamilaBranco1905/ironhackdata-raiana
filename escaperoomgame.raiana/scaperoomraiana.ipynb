# %%
#defines each item inside the room 

roomsname = {
1 :["First room","Couch", "Piano" ," Door A"],
2 :["Second room","Queen Bed","Door A","Door B","Door C"],
3 :["Third room","Double Bed", "Dresser", "Door B"],
4 :["Fourth room","Dining Table", "Door C", "Door D"]
}

itens= {
"Couch" : [False,"nothing in there"],
"Double Bed" : [True,"you find a key", doors ["Door C"]],
"Dining Table" : [False,"nothing in there"],
"Piano" : [True, "you find a key",doors["Door A"]],
"Queen Bed" : [True, "you find a key", doors["Door B"]], 
"Dresser" : [True,"you find a key in the dresser!", doors["Door D"]]
}
#door
doors{
"Door A" :[False,roomsname(1),roomsname(2)],
"Door B" : [False,roomsname(2),roomsname(3)],
"Door C" : [False,roomsname(2),roomsname(4)],
"Door D" : [False,roomsname(4),"outside"]
}

    
gamestatusdeafault = {
    "current_room": game_room,
    "keys_collected": [],
    "target_room": outside
    "open_doors": [],
}



#starts games calls playing function for first room
def start():
    print ("start sentence")
    gamestatus = gamestatusdefault.copy()
    plays()
#reads and update games status, shows objects and doors in the room     
def plays():
#checks if player is in target room
    if gamestatus["current_room"] == gamestatus["target_room"]
        print("congrats")
#if player is in target room resets all variables and starts new game        
        reset()
#if player is not in target room go to function to explore room
    else 
        explore(gamestatus["current_room"])
    
#has to describe objects inside the room, call function to interact and update their status 
def explore (room):
        print ("You are in the %s which contains %s%s%s%s" %roomsname.value(room))
        interact = str(input("Wich object do you want to interact with?"))
#if player interacts with invalid object restarts room      
        if interact not in itens.keys() or doors.keys():
            print ("please type a valid item")
            plays()
# if player interacts with object with key it will add key to inventorie and update object status            
        elif itens[interact][0] == True:
            print("You found a key")
            itens[interact] = [False,"You already have the key that used to be here"]
            gamestatus["keys_collected"].append(interact)
            plays()
#if player interacts with object without key print object phrase and restart room
        elif itens[interact][0] == False :
            print (itens[interact])[1])
            plays()
#if player interacts with door go to function for door interactions
        elif interact == "Door A" or interact == "Door B" or interact == "Door C" or interact == "Door D":
            door(interact)
            
        plays()
    
#Asks for key, opens door, takes to the other room tells if door is locked 
def door (door):
#if door is open go to function for room change
    if doors[door][0] == True:
        movement(door)
        break
#if door in closed check for key 
    elif doors[door][0] == False:
#if player has key open door and go to function for room change 
        if door in gamestatus("keys_collected"):
            print ("You've opened the door")
            doors[door][0] = True
            movement (door)
# if player doesn't have key restart room        
        else:
            print ("You don't have the required key")
            plays()   
   
            
def movement(door): 
#checks in wich of the rooms associated with the door player is 
    if doors.values[1] == gamestatus("current_room"):
#move player to the room associate with the door that he is not currently
        game_room =  doors.values(2)
    elif doors.values[2] == gamestatus("current_room"):
        game_room == doors.values(1)
#restarts room
    plays()


def reset ():
    itens= {
        "couch" = [False,"nothing in there"]
        "doublebed" = [True,"you find a key", keys ["Door C"]]
        "diningtable" = [False,"nothing in there"]
        piano = [True, "you find a key",keys["Door A"]]
        queenbed = [True, "you find a key", keys ["Door B"]] 
        dresser = [True,"you find a key in the dresser!", keys ["Door D"]]
            }
    doors{
        "Door A" = [False,roomsname(1),roomsname(2)]
        "Door B" = [False,roomsname(2),roomsname(3)]
        "Door C" = [False,roomsname(2),roomsname(4)]
        "Door D" = [False,roomsname(4),"outside"]
        }

    keys{
        "Door A" = [False,roomsname(1),roomsname(2)]
        "Door B" = [False,roomsname(2),roomsname(3)]
        "Door C" = [False,roomsname(2),roomsname(4)]
        "Door D" = [False,roomsname(4),"outside"
        }
    replay = str(input("Dou you wanna play again?")
    if replay == "Yes":
        start()
# Out:
#   File "<ipython-input-4-d02caa654a38>", line 1
#     Game Room
#             ^
# SyntaxError: invalid syntax

# %%
()
